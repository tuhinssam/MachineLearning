# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
import numpy as np

# %%
t = np.arange(0.,5.,0.2)
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
# Out:
# [<matplotlib.lines.Line2D at 0x1a9c9c65c50>,
#  <matplotlib.lines.Line2D at 0x1a9c9c65da0>,
#  <matplotlib.lines.Line2D at 0x1a9c9c750f0>]

# %%
data = {'a': np.arange(50),
'c': np.random.randint(0, 50, 50),
'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100
plt.scatter('a', 'b',c='c',s='d',data=data)

# %%
plt.scatter

# %%
#subplots in a single plot
names = ['grp-a','grp-b','grp-c']
values = [1, 10, 100]

#define figure size
plt.figure(1,figsize=(9,3))

plt.subplot(131)
plt.bar(names,values)

plt.subplot(132)
plt.scatter(names,values)

plt.subplot(133)
plt.plot(names,values)
plt.suptitle('Ctegorical Plotting')
# Out:
# Text(0.5, 0.98, 'Ctegorical Plotting')

# %%
plt.subplot
# Out:
# <function matplotlib.pyplot.subplot(*args, **kwargs)>

# %%
x=[1,2,3,4]
y=[1,4,9,16]

# %%
plt.plot(x,y,linewidth=4.0)

# %%
line, = plt.plot(x,y,'*')

# %%
x1=[1,3,5,7]
x2=[2,4,6,8]
y1=[1,9,25,49]
y2=[8,64,216,512]
lines = plt.plot(x1,y1,x2,y2)
plt.title("common test")
plt.grid(True)
plt.setp(lines,color='r',linewidth=2.0)
# Out:
# [None, None, None, None]
